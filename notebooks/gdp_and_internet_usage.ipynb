# %% [markdown]
# ## 3. Import the required packages with their customary aliases as follows:
#
#     import pandas as pd
#     import numpy as np
#     import matplotlib.pyplot as plt
#     import seaborn as sns

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 4. Use the %matplotlib inline magic command so that your plots show in the notebook without having to call plt.show() every time.

# %%
# %matplotlib inline

# %% [markdown]
# ## 5. Using the pandas read_csv() method, read the GDP dataset into your notebook as a DataFrame called gdp_df. Take a look at the first 6 rows.

# %%
gdp_df = pd.read_csv('../data/gdp_percapita.csv', nrows = 6868)

# %%
gdp_df.head(6)
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2019  2065.036398              NaN
# 1     Afghanistan  2018  2033.779002              NaN
# 2     Afghanistan  2017  2058.383832              NaN
# 3     Afghanistan  2016  2057.062164              NaN
# 4     Afghanistan  2015  2068.265904              NaN
# 5     Afghanistan  2014  2102.385234              NaN

# %% [markdown]
# ## 6. Repeat for the internet use dataset. Call this DataFrame internet_df. Take a look at the first six rows.

# %%
internet_df = pd.read_csv('../data/internet_use.csv', nrows = 4495)

# %%
internet_df.head(6)
# Out:
#   Country or Area  Year     Value  Value Footnotes
# 0     Afghanistan  2014  6.390000              NaN
# 1     Afghanistan  2013  5.900000              NaN
# 2     Afghanistan  2012  5.454545              NaN
# 3     Afghanistan  2011  5.000000              NaN
# 4     Afghanistan  2010  4.000000              NaN
# 5     Afghanistan  2009  3.550000              NaN

# %% [markdown]
# ## 7. Look at the shape of each DataFrame - how many rows? How many columns?

# %%
internet_df.shape
# Out:
# (4495, 4)

# %%
gdp_df.shape
# Out:
# (6868, 4)

# %% [markdown]
# ## 8. Take a look at the datatypes for the columns in each DataFrame.

# %%
type(gdp_df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(internet_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## 9. Take a look at the last 10 rows of each DataFrame in turn.

# %%
gdp_df.tail(10)
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 6858        Zimbabwe  1999  3600.849291              NaN
# 6859        Zimbabwe  1998  3653.920016              NaN
# 6860        Zimbabwe  1997  3580.048793              NaN
# 6861        Zimbabwe  1996  3520.430146              NaN
# 6862        Zimbabwe  1995  3226.413930              NaN
# 6863        Zimbabwe  1994  3263.934978              NaN
# 6864        Zimbabwe  1993  3033.504852              NaN
# 6865        Zimbabwe  1992  3054.889178              NaN
# 6866        Zimbabwe  1991  3426.598094              NaN
# 6867        Zimbabwe  1990  3324.348171              NaN

# %%
internet_df.tail(10)
# Out:
#      Country or Area  Year     Value  Value Footnotes
# 4485        Zimbabwe  2002  3.994356              NaN
# 4486        Zimbabwe  2001  0.799846              NaN
# 4487        Zimbabwe  2000  0.401434              NaN
# 4488        Zimbabwe  1999  0.161676              NaN
# 4489        Zimbabwe  1998  0.081648              NaN
# 4490        Zimbabwe  1997  0.033080              NaN
# 4491        Zimbabwe  1996  0.016790              NaN
# 4492        Zimbabwe  1995  0.007684              NaN
# 4493        Zimbabwe  1994  0.001739              NaN
# 4494        Zimbabwe  1990  0.000000              NaN

# %% [markdown]
# ## 10. Drop the value footnotes column from both DataFrames. Check that this worked as expected.

# %%
gdp_df.columns
# Out:
# Index(['Country or Area', 'Year', 'Value', 'Value Footnotes'], dtype='object')

# %%
gdp_df_no_vf = gdp_df.drop(columns = ['Value Footnotes'])

# %%
gdp_df_no_vf.head()
# Out:
#   Country or Area  Year        Value
# 0     Afghanistan  2019  2065.036398
# 1     Afghanistan  2018  2033.779002
# 2     Afghanistan  2017  2058.383832
# 3     Afghanistan  2016  2057.062164
# 4     Afghanistan  2015  2068.265904

# %%
internet_df_no_vf = internet_df.drop(columns = ['Value Footnotes'])
internet_df_no_vf.head()
# Out:
#   Country or Area  Year     Value
# 0     Afghanistan  2014  6.390000
# 1     Afghanistan  2013  5.900000
# 2     Afghanistan  2012  5.454545
# 3     Afghanistan  2011  5.000000
# 4     Afghanistan  2010  4.000000

# %% [markdown]
# ## 11. Change the columns for the Internet Users DataFrame to ‘Country’, ‘Year’, and ‘Internet_Users_Pct’.

# %%
internet_df_no_vf.columns = ['Country', 'Year', 'Internet_Users_Pct']

# %%
internet_df_no_vf.head()
# Out:
#        Country  Year  Internet_Users_Pct
# 0  Afghanistan  2014            6.390000
# 1  Afghanistan  2013            5.900000
# 2  Afghanistan  2012            5.454545
# 3  Afghanistan  2011            5.000000
# 4  Afghanistan  2010            4.000000

# %% [markdown]
# ## 12. Change the columns for the GDP Per Capita DataFrame to ‘Country’, ‘Year’, and ‘GDP_Per_Capita’.

# %%
gdp_df_no_vf.columns = ['Country', 'Year', 'GDP_per_Capita']

# %%
gdp_df_no_vf.head()
# Out:
#        Country  Year  GDP_per_Capita
# 0  Afghanistan  2019     2065.036398
# 1  Afghanistan  2018     2033.779002
# 2  Afghanistan  2017     2058.383832
# 3  Afghanistan  2016     2057.062164
# 4  Afghanistan  2015     2068.265904

# %% [markdown]
# ## 13. Merge the two DataFrames to one. Merge all rows from each of the two DataFrames. Call the new DataFrame gdp_and_internet_use.

# %%
gdp_and_internet_use = pd.merge(gdp_df_no_vf, internet_df_no_vf)

# %%
gdp_and_internet_use = pd.merge(gdp_df_no_vf, internet_df_no_vf, on = ["Country", "Year"], how = "outer")

# %%
gdp_and_internet_use.head()
# Out:
#        Country  Year  GDP_per_Capita  Internet_Users_Pct
# 0  Afghanistan  2019     2065.036398                 NaN
# 1  Afghanistan  2018     2033.779002                 NaN
# 2  Afghanistan  2017     2058.383832                 NaN
# 3  Afghanistan  2016     2057.062164                 NaN
# 4  Afghanistan  2015     2068.265904                 NaN

# %%
gdp_and_internet_use.tail()
# Out:
#      Country  Year  GDP_per_Capita  Internet_Users_Pct
# 7900   Yemen  1999             NaN            0.056629
# 7901   Yemen  1998             NaN            0.023323
# 7902   Yemen  1997             NaN            0.015025
# 7903   Yemen  1996             NaN            0.000621
# 7904   Yemen  1990             NaN            0.000000

# %% [markdown]
# ## 16. Subset the combined DataFrame to keep only the data for 2004, 2009, and 2014. Check that this happened correctly.

# %%
#gdp_and_internet_use.loc[gdp_and_internet_use.Year.isin([2004, 2009, 2014])]

# %%
year_list = [2004, 2009, 2014]
years = gdp_and_internet_use.query("Year in @year_list")
years
# Out:
#                     Country  Year  GDP_per_Capita  Internet_Users_Pct
# 5               Afghanistan  2014     2102.385234            6.390000
# 10              Afghanistan  2009     1758.904043            3.550000
# 15              Afghanistan  2004     1200.278256            0.105809
# 23                  Albania  2014    11623.866679           60.100000
# 28                  Albania  2009    10346.864199           41.200000
# ...                     ...   ...             ...                 ...
# 7868  Virgin Islands (U.S.)  2009             NaN           27.396510
# 7873  Virgin Islands (U.S.)  2004             NaN           27.377009
# 7885                  Yemen  2014             NaN           22.550000
# 7890                  Yemen  2009             NaN            9.960000
# 7895                  Yemen  2004             NaN            0.881223
#
# [830 rows x 4 columns]

# %% [markdown]
# ## 17. Create three new DataFrames, one for 2004, one for 2009, and one for 2014. Give them meaningful names that aren't too long.

# %%
gdp_and_int_use_2004 = gdp_and_internet_use.query("Year == 2004")
gdp_and_int_use_2004
# Out:
#                     Country  Year  GDP_per_Capita  Internet_Users_Pct
# 15              Afghanistan  2004     1200.278256            0.105809
# 33                  Albania  2004     7604.838002            2.420388
# 63                  Algeria  2004    10058.435939            4.634475
# 93                   Angola  2004     5593.241537            0.464815
# 123     Antigua and Barbuda  2004    18745.681534           24.266544
# ...                     ...   ...             ...                 ...
# 7771     T.F.Y.R. Macedonia  2004             NaN           24.440000
# 7829              Venezuela  2004             NaN            8.404470
# 7853               Viet Nam  2004             NaN            7.642409
# 7873  Virgin Islands (U.S.)  2004             NaN           27.377009
# 7895                  Yemen  2004             NaN            0.881223
#
# [276 rows x 4 columns]

# %%
gdp_and_int_use_2009 = gdp_and_internet_use.query("Year == 2009")
gdp_and_int_use_2009
# Out:
#                     Country  Year  GDP_per_Capita  Internet_Users_Pct
# 10              Afghanistan  2009     1758.904043             3.55000
# 28                  Albania  2009    10346.864199            41.20000
# 58                  Algeria  2009    10782.361398            11.23000
# 88                   Angola  2009     7643.493749             6.00000
# 118     Antigua and Barbuda  2009    20046.839017            42.00000
# ...                     ...   ...             ...                 ...
# 7766     T.F.Y.R. Macedonia  2009             NaN            51.77000
# 7824              Venezuela  2009             NaN            32.70000
# 7848               Viet Nam  2009             NaN            26.55000
# 7868  Virgin Islands (U.S.)  2009             NaN            27.39651
# 7890                  Yemen  2009             NaN             9.96000
#
# [277 rows x 4 columns]

# %%
gdp_and_int_use_2014 = gdp_and_internet_use.query("Year == 2014")
gdp_and_int_use_2014
# Out:
#                   Country  Year  GDP_per_Capita  Internet_Users_Pct
# 0             Afghanistan  2014     2102.385234                6.39
# 13                Albania  2014    11623.866679               60.10
# 34                Algeria  2014    11512.705405               18.09
# 56                 Angola  2014     8239.828837               21.26
# 76    Antigua and Barbuda  2014    18104.241470               64.00
# ...                   ...   ...             ...                 ...
# 3351              Uruguay  2014    20582.168953               61.46
# 3373           Uzbekistan  2014     5764.492705               43.55
# 3394              Vanuatu  2014     3116.077025               18.80
# 3414               Zambia  2014     3450.046561               17.34
# 3436             Zimbabwe  2014     2955.240287               19.89
#
# [163 rows x 4 columns]

# %%
iup_2014 = gdp_and_int_use_2014.sort_values(by = 'Internet_Users_Pct', ascending = False)
iup_2014
# Out:
#           Country  Year  GDP_per_Capita  Internet_Users_Pct
# 1381      Iceland  2014    49652.149500               98.16
# 372       Bermuda  2014    77361.104881               96.80
# 2296       Norway  2014    62589.373548               96.30
# 854       Denmark  2014    52214.537753               95.99
# 1798   Luxembourg  2014   108760.916030               94.67
# ...           ...   ...             ...                 ...
# 2122      Myanmar  2014     4020.037369                2.10
# 2256        Niger  2014     1127.615541                1.95
# 1261       Guinea  2014     2061.760973                1.72
# 540       Burundi  2014      886.235777                1.38
# 3087  Timor-Leste  2014     3264.568070                1.14
#
# [163 rows x 4 columns]

# %%
iup_2009 = gdp_and_int_use_2009.sort_values(by = 'Internet_Users_Pct', ascending = False)
iup_2009
# Out:
#                   Country  Year  GDP_per_Capita  Internet_Users_Pct
# 2630              Iceland  2009    48177.084123               93.00
# 4653               Norway  2009    61886.564498               92.08
# 6014               Sweden  2009    45638.035577               91.00
# 4443          Netherlands  2009    51772.424928               89.63
# 3696           Luxembourg  2009   104932.811953               87.31
# ...                   ...   ...             ...                 ...
# 6194           The Gambia  2009     2283.183556                 NaN
# 6612  Upper middle income  2009    11212.934078                 NaN
# 6732              Vietnam  2009     4830.304958                 NaN
# 6762   West Bank and Gaza  2009     5250.116075                 NaN
# 6788                World  2009    13396.524163                 NaN
#
# [277 rows x 4 columns]

# %% [markdown]
# ## 18. Which country had the highest percentage of internet users in 2014? What was the percentage? (Try typing the first 3 letters of your DataFrame name and hitting the tab key for auto-complete options).

# %%
iup_2004 = gdp_and_int_use_2004.sort_values(by = 'Internet_Users_Pct', ascending = False)
iup_2004
# Out:
#                   Country  Year  GDP_per_Capita  Internet_Users_Pct
# 6019               Sweden  2004    44496.023401               83.89
# 2635              Iceland  2004    45145.545658               83.88
# 1462              Denmark  2004    50607.628971               80.93
# 4658               Norway  2004    60893.410993               77.69
# 7400      Korea (Rep. of)  2004             NaN               72.70
# ...                   ...   ...             ...                 ...
# 6437               Tuvalu  2004     3336.952920                 NaN
# 6617  Upper middle income  2004     8567.061394                 NaN
# 6737              Vietnam  2004     3689.732423                 NaN
# 6767   West Bank and Gaza  2004     4485.525458                 NaN
# 6793                World  2004    12077.823821                 NaN
#
# [276 rows x 4 columns]

# %% [markdown]
# ## from Chris's demo

# %%
iup_2014.loc[iup_2014.Internet_Users_Pct == iup_2014.Internet_Users_Pct.min()]
# Out:
#           Country  Year  GDP_per_Capita  Internet_Users_Pct
# 3087  Timor-Leste  2014      3264.56807                1.14

# %% [markdown]
# ## 21. Which country had the highest gdp per capita in 2014? What was the gdp per capita?

# %%
gdppc_2014 = gdp_and_int_use_2014.sort_values(by = 'GDP_per_Capita', ascending = False)
gdppc_2014
# Out:
#              Country  Year  GDP_per_Capita  Internet_Users_Pct
# 1798      Luxembourg  2014   108760.916030               94.67
# 2542           Qatar  2014    95578.416973               91.49
# 2751       Singapore  2014    87808.663157               82.00
# 372          Bermuda  2014    77361.104881               96.80
# 627   Cayman Islands  2014    66207.447230               74.10
# ...              ...   ...             ...                 ...
# 3098            Togo  2014     1404.132938                5.70
# 2102      Mozambique  2014     1217.090210                5.94
# 2256           Niger  2014     1127.615541                1.95
# 1842          Malawi  2014     1027.208496                5.83
# 540          Burundi  2014      886.235777                1.38
#
# [163 rows x 4 columns]

# %%
gdppc_2009 = gdp_and_int_use_2009.sort_values(by = 'GDP_per_Capita', ascending = False)
gdppc_2009
# Out:
#                     Country  Year  GDP_per_Capita  Internet_Users_Pct
# 3696             Luxembourg  2009   104932.811953            87.31000
# 3726       Macao SAR, China  2009    95939.340822                 NaN
# 566                 Bermuda  2009    89961.982744            83.25000
# 5143                  Qatar  2009    89954.519993            53.10000
# 5301             San Marino  2009    76736.328963            54.21000
# ...                     ...   ...             ...                 ...
# 7766     T.F.Y.R. Macedonia  2009             NaN            51.77000
# 7824              Venezuela  2009             NaN            32.70000
# 7848               Viet Nam  2009             NaN            26.55000
# 7868  Virgin Islands (U.S.)  2009             NaN            27.39651
# 7890                  Yemen  2009             NaN             9.96000
#
# [277 rows x 4 columns]

# %%
gdppc_2004 = gdp_and_int_use_2004.sort_values(by = 'GDP_per_Capita', ascending = False)
gdppc_2004
# Out:
#                     Country  Year  GDP_per_Capita  Internet_Users_Pct
# 3701             Luxembourg  2004   102708.212547           65.880000
# 6527   United Arab Emirates  2004    97758.023345           30.131296
# 5148                  Qatar  2004    93748.301216           20.701648
# 571                 Bermuda  2004    90195.811033           60.990867
# 5306             San Marino  2004    80391.828516           50.566343
# ...                     ...   ...             ...                 ...
# 7771     T.F.Y.R. Macedonia  2004             NaN           24.440000
# 7829              Venezuela  2004             NaN            8.404470
# 7853               Viet Nam  2004             NaN            7.642409
# 7873  Virgin Islands (U.S.)  2004             NaN           27.377009
# 7895                  Yemen  2004             NaN            0.881223
#
# [276 rows x 4 columns]

# %% [markdown]
# ## 22. Which country had the lowest gdp per capita in 2014? What was the gdp per capita?

# %%
gdp_and_int_use_2014.sort_values(by = 'GDP_per_Capita', ascending = True)
# Out:
#              Country  Year  GDP_per_Capita  Internet_Users_Pct
# 540          Burundi  2014      886.235777                1.38
# 1842          Malawi  2014     1027.208496                5.83
# 2256           Niger  2014     1127.615541                1.95
# 2102      Mozambique  2014     1217.090210                5.94
# 3098            Togo  2014     1404.132938                5.70
# ...              ...   ...             ...                 ...
# 627   Cayman Islands  2014    66207.447230               74.10
# 372          Bermuda  2014    77361.104881               96.80
# 2751       Singapore  2014    87808.663157               82.00
# 2542           Qatar  2014    95578.416973               91.49
# 1798      Luxembourg  2014   108760.916030               94.67
#
# [163 rows x 4 columns]

# %%
#gdp_and_int_use_2009.sort_values(by = 'GDP_per_Capita', ascending = True)

# %%
#gdp_and_int_use_2004.sort_values(by = 'GDP_per_Capita', ascending = True)

# %% [markdown]
# ## 23. Create some scatterplots:
#         a. 2004 Percent Using the Internet vs GDP Per Capita
#         b. 2009 Percent Using the Internet vs GDP Per Capita
#         c. 2014 Percent Using the Internet vs GDP Per Capita

# %%
#gdp_and_int_use_2004.plot.scatter(x = 'Internet_Users_Pct', y = "GDP_per_Capita")
#plt.scatter(iup_2004.Internet_Users_Pct, gdppc_2004.GDP_per_Capita)
plt.scatter(iup_2004.Internet_Users_Pct, iup_2004.GDP_per_Capita);

# %%
#gdp_and_int_use_2009.plot.scatter(x = 'Internet_Users_Pct', y = "GDP_per_Capita")
plt.scatter(iup_2009.Internet_Users_Pct, iup_2009.GDP_per_Capita);

# %%
#gdp_and_int_use_2014.plot.scatter(x = 'Internet_Users_Pct', y = "GDP_per_Capita")
plt.scatter(iup_2014.Internet_Users_Pct, iup_2014.GDP_per_Capita);

# %% [markdown]
# ## 24. Are there differences across years? What do the plots tell you about any relationship between these two variables? Enter your observations as a markdown cell.
#
# ### Answer
#     As the years go, the percentage of internet users increases dramatically from 2004-2014.
#     The GDP per capatia also spreads out more evenly to suggest an increase in internet usage correlates to an increase in GDP.

# %% [markdown]
# ## 25.Look at the distribution of gdp per capita values for 2014. Is it unimodal? - Yes

# %%
sns.distplot(gdp_2014.GDP_per_Capita, bins = 7);
# Out:
# C:\Users\16159\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.hist(gdppc_2014[('GDP_per_Capita')])
plt.title("GDP per Capita in 2014")
plt.xlabel("GDP per Capita")
plt.ylabel("Internet Users")
plt.show;

# %% [markdown]
# ## 26. Look at the distribution of Internet Use for 2014. Is it unimodal? - No

# %%
plt.hist(iup_2014[('Internet_Users_Pct')])
plt.title("Internet Use in 2014")
plt.xlabel("Internet Users")
plt.ylabel("GDP per Capita")
plt.show;

# %% [markdown]
# ## 27. What are the top 5 countries in terms of internet use in 2014?

# %%
iup_2014.sort_values(by = ["Internet_Users_Pct"], ascending = False).head()
# Out:
#          Country  Year  GDP_per_Capita  Internet_Users_Pct
# 1381     Iceland  2014    49652.149500               98.16
# 372      Bermuda  2014    77361.104881               96.80
# 2296      Norway  2014    62589.373548               96.30
# 854      Denmark  2014    52214.537753               95.99
# 1798  Luxembourg  2014   108760.916030               94.67

# %%
top_5_iup_2014 = iup_2014[['Country', 'Internet_Users_Pct']]
top_5_iup_2014.head()
# Out:
#          Country  Internet_Users_Pct
# 1381     Iceland               98.16
# 372      Bermuda               96.80
# 2296      Norway               96.30
# 854      Denmark               95.99
# 1798  Luxembourg               94.67

# %% [markdown]
# ## 28. Create a DataFrame called top_5_internet from the combined DataFrame that has all three years for the 5 countries that had the greatest 2014 internet usage. You should have 15 rows. Check that this is true.

# %%
country_list = ['Iceland', 'Bermuda', 'Norway', 'Denmark', 'Luxembourg']
top_5_internet = years.query('Country in @country_list')
top_5_internet
# Out:
#          Country  Year  GDP_per_Capita  Internet_Users_Pct
# 561      Bermuda  2014    77361.104881           96.800000
# 566      Bermuda  2009    89961.982744           83.250000
# 571      Bermuda  2004    90195.811033           60.990867
# 1452     Denmark  2014    52214.537753           95.990000
# 1457     Denmark  2009    50274.075696           86.840000
# 1462     Denmark  2004    50607.628971           80.930000
# 2625     Iceland  2014    49652.149500           98.160000
# 2630     Iceland  2009    48177.084123           93.000000
# 2635     Iceland  2004    45145.545658           83.880000
# 3691  Luxembourg  2014   108760.916030           94.670000
# 3696  Luxembourg  2009   104932.811953           87.310000
# 3701  Luxembourg  2004   102708.212547           65.880000
# 4648      Norway  2014    62589.373548           96.300000
# 4653      Norway  2009    61886.564498           92.080000
# 4658      Norway  2004    60893.410993           77.690000

# %% [markdown]
# ## 29. Create a seaborn FacetGrid to show the internet usage trend across the years 2004, 2009, and 2014 for these 5 countries (those with the highest reported internet use in 2014). Which country had the greatest growth between 2004 and 2014? - Bermuda

# %%
graph = sns.FacetGrid(top_5_internet, col = 'Country')
graph.map(sns.regplot, 'Year', 'Internet_Users_Pct')
plt.show;

# %%
sns.relplot(data = top_5_internet, x = "Year", y = "Internet_Users_Pct", kind = 'line', hue = "Country");

# %%
graph = sns.FacetGrid(top_5_internet, hue = 'Country')
graph.map(sns.regplot, 'Year', 'Internet_Users_Pct').add_legend()
plt.show;

# %% [markdown]
# ## 30. Repeat the steps above to look at the trend for the 5 countries with the lowest 2014 internet usage. Which country has consistently had the least internet use? - Burundi

# %%
bottom_iup_2014 = gdp_and_int_use_2014.sort_values(by = 'Internet_Users_Pct', ascending = True)
bottom_iup_2014
# Out:
#            Country  Year  GDP_per_Capita  Internet_Users_Pct
# 3087   Timor-Leste  2014     3264.568070                1.14
# 540        Burundi  2014      886.235777                1.38
# 1261        Guinea  2014     2061.760973                1.72
# 2256         Niger  2014     1127.615541                1.95
# 2728  Sierra Leone  2014     1997.511853                2.10
# ...            ...   ...             ...                 ...
# 1798    Luxembourg  2014   108760.916030               94.67
# 854        Denmark  2014    52214.537753               95.99
# 2296        Norway  2014    62589.373548               96.30
# 372        Bermuda  2014    77361.104881               96.80
# 1381       Iceland  2014    49652.149500               98.16
#
# [163 rows x 4 columns]

# %%
bottom_country_list = ['Timor-Leste', 'Burundi', 'Guinea', 'Niger', 'Sierra Leone']
bottom_5_internet = years.query('Country in @bottom_country_list')
bottom_5_internet
# Out:
#            Country  Year  GDP_per_Capita  Internet_Users_Pct
# 827        Burundi  2014      886.235777            1.380000
# 832        Burundi  2009      831.564131            0.900000
# 837        Burundi  2004      817.460585            0.349060
# 2326        Guinea  2014     2061.760973            1.720000
# 2331        Guinea  2009     1825.576637            0.940000
# 2336        Guinea  2004     1778.079082            0.508819
# 4528         Niger  2014     1127.615541            1.950000
# 4533         Niger  2009      992.409977            0.760000
# 4538         Niger  2004      929.883920            0.189934
# 5434  Sierra Leone  2014     1997.511853            2.100000
# 5439  Sierra Leone  2009     1372.392285            0.260000
# 5444  Sierra Leone  2004     1237.630244            0.203008
# 6219   Timor-Leste  2014     3264.568070            1.140000
# 6224   Timor-Leste  2009     2724.770973            0.185252
# ...

# %%
graph = sns.FacetGrid(bottom_5_internet, col = 'Country')
graph.map(sns.regplot, 'Year', 'Internet_Users_Pct')
plt.show;

# %% [markdown]
# ## 31. Find the top 5 countries for 2014 in terms of GDP per capita; create a DataFrame to look at 10-year trends (use 2004, 2009, 2014 to look at the 10-year trend) in gdp per capita for the 5 countries with the highest 2014 GDP per capita. Use a seaborn facet grid for this.

# %%
gdppc_2014
# Out:
#              Country  Year  GDP_per_Capita  Internet_Users_Pct
# 1798      Luxembourg  2014   108760.916030               94.67
# 2542           Qatar  2014    95578.416973               91.49
# 2751       Singapore  2014    87808.663157               82.00
# 372          Bermuda  2014    77361.104881               96.80
# 627   Cayman Islands  2014    66207.447230               74.10
# ...              ...   ...             ...                 ...
# 3098            Togo  2014     1404.132938                5.70
# 2102      Mozambique  2014     1217.090210                5.94
# 2256           Niger  2014     1127.615541                1.95
# 1842          Malawi  2014     1027.208496                5.83
# 540          Burundi  2014      886.235777                1.38
#
# [163 rows x 4 columns]

# %%
top_gdp_country_list = ['Luxembourg', 'Qatar', 'Singapore', 'Bermuda', 'Cayman Islands']
top_5_gdp = years.query('Country in @top_gdp_country_list')
top_5_gdp
# Out:
#              Country  Year  GDP_per_Capita  Internet_Users_Pct
# 561          Bermuda  2014    77361.104881           96.800000
# 566          Bermuda  2009    89961.982744           83.250000
# 571          Bermuda  2004    90195.811033           60.990867
# 1033  Cayman Islands  2014    66207.447230           74.100000
# 1038  Cayman Islands  2009    70300.334857           64.500000
# 3691      Luxembourg  2014   108760.916030           94.670000
# 3696      Luxembourg  2009   104932.811953           87.310000
# 3701      Luxembourg  2004   102708.212547           65.880000
# 5138           Qatar  2014    95578.416973           91.490000
# 5143           Qatar  2009    89954.519993           53.100000
# 5148           Qatar  2004    93748.301216           20.701648
# 5464       Singapore  2014    87808.663157           82.000000
# 5469       Singapore  2009    69466.581746           69.000000
# 5474       Singapore  2004    63901.716368           62.000000

# %%
graph = sns.FacetGrid(top_5_gdp, col = 'Country')
graph.map(sns.regplot, 'Year', 'GDP_per_Capita')
plt.show;

# %% [markdown]
# ## 32. Repeat this one more time to look at 10-year trend for the 5 countries for 2014 with the lowest GDP per capita.

# %%
bottom_gdp_country_list = ['Togo', 'Mozambique', 'Niger', 'Malawi', 'Burundi']
bottom_5_gdp = years.query('Country in @bottom_gdp_country_list')
bottom_5_gdp
# Out:
#          Country  Year  GDP_per_Capita  Internet_Users_Pct
# 827      Burundi  2014      886.235777            1.380000
# 832      Burundi  2009      831.564131            0.900000
# 837      Burundi  2004      817.460585            0.349060
# 3781      Malawi  2014     1027.208496            5.830000
# 3786      Malawi  2009      932.867635            1.070000
# 3791      Malawi  2004      775.346132            0.347505
# 4302  Mozambique  2014     1217.090210            5.940000
# 4307  Mozambique  2009      991.323181            2.680000
# 4312  Mozambique  2004      792.727155            0.679448
# 4528       Niger  2014     1127.615541            1.950000
# 4533       Niger  2009      992.409977            0.760000
# 4538       Niger  2004      929.883920            0.189934
# 6239        Togo  2014     1404.132938            5.700000
# 6244        Togo  2009     1186.114587            2.600000
# 6249        Togo  2004     1276.676272            1.500000

# %%
graph = sns.FacetGrid(bottom_5_gdp, col = 'Country')
graph.map(sns.regplot, 'Year', 'GDP_per_Capita')
plt.show;

# %% [markdown]
# ## 33. Is there anything surprising or unusual in any of these plots? Searching on the internet, can you find any possible explanations for unusual findings?
#     The Cayman Islands does not have data for 2004 and Bermuda's GDP decreased from 2004 to 2014 due in part to the 2008 global economic crisis.

# %%
whos% DataFrame
# Out:
# Variable               Type         Data/Info
# ---------------------------------------------
# all_data               DataFrame              Country  Year  <...>n[11363 rows x 4 columns]
# bottom_5_gdp           DataFrame             Country  Year  G<...>76272            1.500000
# bottom_5_internet      DataFrame               Country  Year <...>08056                 NaN
# bottom_iup_2014        DataFrame               Country  Year <...>n\n[163 rows x 4 columns]
# countries              DataFrame             Country  Year  G<...>10993           77.690000
# gdp_2014               DataFrame                 Country  Yea<...>n\n[163 rows x 4 columns]
# gdp_and_int_use_2004   DataFrame                        Count<...>n\n[276 rows x 4 columns]
# gdp_and_int_use_2009   DataFrame                        Count<...>n\n[277 rows x 4 columns]
# gdp_and_int_use_2014   DataFrame                      Country<...>n\n[163 rows x 4 columns]
# ...
